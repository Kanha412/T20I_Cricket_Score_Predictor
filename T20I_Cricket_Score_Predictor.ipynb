# %% [markdown]
# <a href="https://colab.research.google.com/github/Kanha412/T20I_Cricket_Score_Predictor/blob/main/T20I_Cricket_Score_Predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('t20i_info.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0           0         2    Australia    Sri Lanka   0.1     0
# 1           1         2    Australia    Sri Lanka   0.2     0
# 2           2         2    Australia    Sri Lanka   0.3     1
# 3           3         2    Australia    Sri Lanka   0.4     2
# 4           4         2    Australia    Sri Lanka   0.5     0
#
#   player_dismissed city                     venue
# 0                0  NaN  Melbourne Cricket Ground
# 1                0  NaN  Melbourne Cricket Ground
# 2                0  NaN  Melbourne Cricket Ground
# 3                0  NaN  Melbourne Cricket Ground
# 4                0  NaN  Melbourne Cricket Ground

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8548
# venue                  0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# venue
# Dubai International Cricket Stadium        2969
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: count, dtype: int64

# %%
cities = np.where(df['city'].isnull(), df['venue'].str.split().apply(lambda x : x[0]), df['city'])

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df['city'].value_counts()
# Out:
# city
# Colombo          4086
# Mirpur           3420
# Johannesburg     3331
# Dubai            2969
# Auckland         2532
#                  ...
# Nairobi           123
# Potchefstroom     122
# Dharamsala        122
# Ahmedabad         121
# Carrara            64
# Name: count, Length: 86, dtype: int64

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed       city                     venue
# 0                    0  Melbourne  Melbourne Cricket Ground
# ...

# %%
df['current_score'] = df.groupby('match_id')['runs'].cumsum()

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed       city                     venue  current_score
# 0                    0  Melbourne  Melbourne Cricket Ground              0
# ...

# %%
df['over'] = df['ball'].apply(lambda x : str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x : str(x).split(".")[1])

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed       city                     venue  current_score  \
# 0                    0  Melbourne  Melbourne Cricket Ground              0
# ...

# %%
df['balls_bowled'] = (df['over'].astype('int')*6 + df['ball_no'].astype('int'))

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed       city                     venue  current_score  \
# 0                    0  Melbourne  Melbourne Cricket Ground              0
# ...

# %%
df['balls_left'] = 120 - df['balls_bowled']

# %%
df['balls_left'] = df['balls_left'].apply(lambda x: 0 if x < 0 else x)

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed       city                     venue  current_score  \
# 0                    0  Melbourne  Melbourne Cricket Ground              0
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0           0         2    Australia    Sri Lanka   0.1     0
# 1           1         2    Australia    Sri Lanka   0.2     0
# 2           2         2    Australia    Sri Lanka   0.3     1
# 3           3         2    Australia    Sri Lanka   0.4     2
# 4           4         2    Australia    Sri Lanka   0.5     0
#
#   player_dismissed       city                     venue  current_score over  \
# 0                0  Melbourne  Melbourne Cricket Ground              0    0
# 1                0  Melbourne  Melbourne Cricket Ground              0    0
# 2                0  Melbourne  Melbourne Cricket Ground              1    0
# 3                0  Melbourne  Melbourne Cricket Ground              3    0
# 4                0  Melbourne  Melbourne Cricket Ground              3    0
#
#   ball_no  balls_bowled  balls_left
# 0       1             1         119
# 1       2             2         118
# ...

# %%
df['player_dismissed'].apply(lambda x: 1 if x != '0' else '0')
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 63883    0
# 63884    0
# 63885    1
# 63886    0
# 63887    0
# Name: player_dismissed, Length: 50501, dtype: object

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x: 1 if x != '0' else 0)

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#        player_dismissed       city                     venue  current_score  \
# 0                     0  Melbourne  Melbourne Cricket Ground              0
# ...

# %%
df['player_dismissed'] = df['player_dismissed'].astype('int')

# %%
df['player_dismissed'] = df.groupby('match_id')['player_dismissed'].cumsum()

# %%
df['wickets_left'] = 10 - df['player_dismissed']

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#        player_dismissed       city                     venue  current_score  \
# 0                     0  Melbourne  Melbourne Cricket Ground              0
# ...

# %%
df.sample(5)
# Out:
#        Unnamed: 0  match_id  batting_team  bowling_team  ball  runs  \
# 51764          35       789   West Indies         India   5.2     1
# 33554           3       564      Pakistan       England   0.4     0
# 56086          96       831  South Africa    Bangladesh  15.5     1
# 52285          52       795     Australia   West Indies   8.3     4
# 15279          89       224     Australia  South Africa  14.1     1
#
#        player_dismissed       city                          venue  \
# 51764                 0     Mirpur  Shere Bangla National Stadium
# 33554                 0   Barbados    Kensington Oval, Bridgetown
# 56086                 4     Mirpur  Shere Bangla National Stadium
# 52285                 3     Mirpur  Shere Bangla National Stadium
# 15279                 2  Cape Town                       Newlands
#
#        current_score over ball_no  balls_bowled  balls_left  wickets_left
# 51764             19    5       2            32          88            10
# ...

# %%
df['crr'] = (df['current_score']*6) / df['balls_bowled']

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#        player_dismissed       city                     venue  current_score  \
# 0                     0  Melbourne  Melbourne Cricket Ground              0
# ...

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30)['runs'].sum().values.tolist())

# %%
df['last_five'] = last_five

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#        player_dismissed       city                     venue  current_score  \
# 0                     0  Melbourne  Melbourne Cricket Ground              0
# ...

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df
# Out:
#        match_id  runs_x  Unnamed: 0 batting_team bowling_team  ball  runs_y  \
# 0             2     168           0    Australia    Sri Lanka   0.1       0
# 1             2     168           1    Australia    Sri Lanka   0.2       0
# 2             2     168           2    Australia    Sri Lanka   0.3       1
# 3             2     168           3    Australia    Sri Lanka   0.4       2
# 4             2     168           4    Australia    Sri Lanka   0.5       0
# ...         ...     ...         ...          ...          ...   ...     ...
# 50496       964     128         121    Sri Lanka    Australia  19.3       1
# 50497       964     128         122    Sri Lanka    Australia  19.4       0
# 50498       964     128         123    Sri Lanka    Australia  19.5       0
# 50499       964     128         124    Sri Lanka    Australia  19.6       2
# 50500       964     128         125    Sri Lanka    Australia  19.7       1
#
# ...

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df.dropna(inplace=True)
# Out:
# <ipython-input-102-3665e38311c9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df
# Out:
#       batting_team bowling_team             city  current_score  balls_left  \
# 39726  West Indies   Bangladesh           Mirpur             36          85
# 20238    Australia    Sri Lanka       Nottingham             94          32
# 35937  New Zealand      England       Wellington             74          53
# 34467  West Indies    Australia         Barbados            124          42
# 22971    Australia     Pakistan            Dubai            104          16
# ...            ...          ...              ...            ...         ...
# 37550  West Indies      England         Barbados            168           3
# 31092      England     Pakistan        Abu Dhabi            109          13
# 1648   West Indies     Pakistan        Abu Dhabi             26          84
# 42786  New Zealand     Pakistan            Dubai             72          49
# 466    New Zealand   Bangladesh  Mount Maunganui            128          28
#
#        wickets_left       crr  last_five  runs_x
# ...

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#        batting_team bowling_team          city  current_score  balls_left  \
# 15774       England    Australia     Cape Town            131           9
# 16238   New Zealand        India  Johannesburg            103          37
# 6645   South Africa     Pakistan  Johannesburg             73          55
# 35200   New Zealand      England        London            104          60
# 49359       England  West Indies       Kolkata             44          76
# ...             ...          ...           ...            ...         ...
# 15082  South Africa        India  Johannesburg             41          74
# 23153      Pakistan    Sri Lanka       Colombo             56          78
# 8493       Pakistan    Australia         Dubai             45          85
# 18210   New Zealand      England    Manchester             72          44
# 20809         India  West Indies        London             34          86
#
#        wickets_left        crr  last_five
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
# !pip install xgboost
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# 0.98728595587914
# 1.624888910820975

# %%
eligible_cities
# Out:
# ['Colombo',
#  'Mirpur',
#  'Johannesburg',
#  'Dubai',
#  'Auckland',
#  'Cape Town',
#  'London',
#  'Pallekele',
#  'Barbados',
#  'Sydney',
#  'Melbourne',
#  'Durban',
#  'St Lucia',
#  'Wellington',
#  'Lauderhill',
#  'Hamilton',
#  'Centurion',
#  'Manchester',
#  'Abu Dhabi',
#  'Mumbai',
#  'Nottingham',
#  'Southampton',
#  'Mount Maunganui',
#  'Chittagong',
#  'Kolkata',
#  'Lahore',
#  'Delhi',
#  'Nagpur',
#  'Chandigarh',
#  'Adelaide',
#  'Bangalore',
#  'St Kitts',
#  'Cardiff',
#  'Christchurch',
#  'Trinidad']

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-90640fbed2d2> in <cell line: 2>()
#       1 import pickle
# ----> 2 pickle.dump(pipe,open('pipe.pkl','wb'))
#
# NameError: name 'pipe' is not defined

# %%
eligible_cities.sort()

# %%
# !pip install streamlit -q

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.106.196.90

# %%
! streamlit run app.py & npx localtunnel --port 8501
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.106.196.90:8501
#
# npx: installed 22 in 2.384s
# your url is: https://gold-beans-scream.loca.lt
# 2024-07-10 23:50:57.845 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/app.py", line 6, in <module>
#     pipe = pickle.load(open('pipe.pkl', 'rb'))
# FileNotFoundError: [Errno 2] No such file or directory: 'pipe.pkl'
#   Stopping...
# ^C
